# %% [markdown]
# # Clean pe_contratos
#
#
# ### Goals
# - Como unir contratos_pe com detalhes_pe? [numerocontrato, codigopl]
#
# -Fazer a comparação de valores recebidos em base contratos e base licitações
#
# -Fazer comparação entre numero de contratos com dispensa de licitação em sca_licitacoesdetalhes e em contratos
#
# -Há discrepância entre número de licitações ganha por empresa x e número de contratos assinados?
#
# -O que fazer com Pessoas Físicas em sca_licitacoesdetalhes?
#
# -Integridade de base sca_contrataos detalhes para variável número de licitantes (e.g. CONSTA 0 e teve vários – controlando para a possibilidade de que a respectiva licitação tenha sido revogada)
#
#
# ### Query
#
# ```CREATE TABLE analise_corrupcao_cluster.pe_contratos AS (
#   SELECT *
#   FROM br_gov_despesas_municipais_tce_pe_contratos.contratos
#   WHERE numerodocumentoajustado !~ '[A-Z]+|,')
#   ```
#
# ### Results
#
#  The fields that are most importants, for know, are the key ones **numerodocumentoajustado** and **codigoug** because they are necessary to bind data with different tables.
#
#  Everything seems normal. The correlation between fields also seem fine.
#
#  As usual, there are few companies that share most of the contracts. I did not get the proportions, but this is a interesting investigations topic.
#
# ### Methodology

# %%
from sqlalchemy import create_engine
import pandas as pd
import copy
import seaborn as sns

pd.options.display.max_columns = 999
con = create_engine('postgresql://postgres:AJ2709lO3zdCLP09@35.188.88.232:5432/cts')

# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 12)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.5/dist-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
contratos = pd.read_sql_query('SELECT * FROM analise_corrupcao_cluster.pe_contratos', con)

# %%
detalhes = pd.read_sql_query('SELECT * FROM analise_corrupcao_cluster.sca_licitacoesdetalhes', con)

# %%
contratos = contratos.reset_index()
contratos.head(2)
# Out:
#    index                              unidadegestora esfera  \
# 0      0  Tribunal de Contas do Estado de Pernambuco     E
# 1      1  Tribunal de Contas do Estado de Pernambuco     E
#
#                         municipio anocontrato            cpf_cnpj  \
# 0  Recife                                2010      020.618.434-41
# 1  Recife                                2008  00.028.986/0001-08
#
#   tipodocumento     numerodocumento numerodocumentoajustado  \
# 0           CPF      020.618.434-41             02061843441
# 1          CNPJ  00.028.986/0001-08          00028986000108
#
#                                          razaosocial                 vigencia  \
# 0  MARIA DE FATIMA WAECHTER FINIZOLA             ...  01/12/2010 a 28/02/2011
# 1  ELEVADORES ATLAS SCHINDLER S/A                ...  03/12/2008 a 02/12/2009
#
#                                            objeto  valorcontrato  \
# 0                               3.117 CONSULTORIA       24733.33
# 1  2.010 MANUTENÇÃO E CONSERVAÇÃO DE BENS IMÓVEIS       24000.00
#
#    estagiocontrato situacaocontrato siglaug codigoug codigoefiscoug  \
# 0  Fim de Vigência          Regular  TCE/PE      780         020001
# 1  Fim de Vigência          Regular  TCE/PE      780         020001
#
#   codigoaudinug tipoprocesso numeroprocesso anoprocesso  \
# 0       999.004         None           None        None
# 1       999.004         None           None        None
#
#   portariacomissaolicitacao linkarquivo numerocontrato
# 0                      None        None            079
# 1                      None        None            076

# %%
print('Número de entradas na tabela: ', len(contratos))
# Out:
# Número de entradas na tabela:  119827

# %%
detalhes = detalhes.reset_index()
detalhes.head(2)
# Out:
#    index numerodocumentoajustado  codigopl  codigoug  \
# 0      0                       0    1703.0     623.0
# 1      1                       0     199.0     341.0
#
#                                            ug     nomenatureza  \
# 0  Prefeitura Municipal de São Vicente Férrer          Compras
# 1      Prefeitura Municipal de Joaquim Nabuco  Outros Serviços
#
#       nomemodalidade numeromodalidade  anomodalidade  \
# 0  Pregão Presencial               10         2009.0
# 1    Inexigibilidade                4         2009.0
#
#                                      descricaoobjeto  \
# 0                                       MEDICAMENTOS
# 1  SERVIÇOS PRESTADOS POR PROFISSIONAL DO SETOR A...
#
#                                  especificacaoobjeto situacaolicitacao  \
# 0  MEDICAMENTOS OU COMPONENTES DESTINADOS À MANIP...      Em Andamento
# 1  CONTRATAÇÃO DE CANTORES, PINTORES, POETAS, ART...      Em Andamento
#
#       estagiolicitacao    adjudicada  qtdelicitantes  codigomodalidade  \
# 0  Processo Instaurado  Não Vencedor             0.0               9.0
# 1  Processo Instaurado  Não Vencedor             0.0              11.0
#
#   numeroprocesso  anoprocesso caracteristicaobjeto  \
# 0             65       2009.0            Por Lotes
# 1             20       2009.0   Integral com Itens
#
#                                 objetoconformeedital razaosocial  \
# 0  MEDICAMENTOS OU COMPONENTES DESTINADOS À MANIP...        None
# 1  CONTRATAÇÃO DE CANTORES, PINTORES, POETAS, ART...        None
#
#   datapublicacaohomologacao  totaladjudicadolicitacao resultadohabilitacao  \
# 0                      None                       NaN                 None
# 1                      None                       NaN                 None
#
#   dataemissaoedital datapublicacaohabilitacao  totaladjudicadolicitante
# 0              None                      None                       NaN
# 1              None                      None                       NaN

# %%
print('Número de entradas na tabela: ', len(detalhes))
print('Número de vencedores: ', len(detalhes[detalhes['adjudicada'] == 'Vencedor']))
# Out:
# Número de entradas na tabela:  368522
# Número de vencedores:  158252

# %%
contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119827 entries, 0 to 119826
# Data columns (total 25 columns):
# index                        119827 non-null int64
# unidadegestora               119827 non-null object
# esfera                       119827 non-null object
# municipio                    119827 non-null object
# anocontrato                  119827 non-null object
# cpf_cnpj                     119827 non-null object
# tipodocumento                119827 non-null object
# numerodocumento              119827 non-null object
# numerodocumentoajustado      119827 non-null object
# razaosocial                  119827 non-null object
# vigencia                     119827 non-null object
# objeto                       119827 non-null object
# valorcontrato                119827 non-null float64
# estagiocontrato              119827 non-null object
# situacaocontrato             119827 non-null object
# siglaug                      115064 non-null object
# codigoug                     119827 non-null object
# codigoefiscoug               19109 non-null object
# codigoaudinug                119827 non-null object
# tipoprocesso                 85078 non-null object
# numeroprocesso               85078 non-null object
# anoprocesso                  85078 non-null object
# portariacomissaolicitacao    85078 non-null object
# linkarquivo                  119746 non-null object
# numerocontrato               119827 non-null object
# dtypes: float64(1), int64(1), object(23)
# memory usage: 22.9+ MB

# %%
detalhes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368522 entries, 0 to 368521
# Data columns (total 27 columns):
# index                        368522 non-null int64
# numerodocumentoajustado      368522 non-null object
# codigopl                     368522 non-null float64
# codigoug                     368522 non-null float64
# ug                           368522 non-null object
# nomenatureza                 368403 non-null object
# nomemodalidade               368522 non-null object
# numeromodalidade             368522 non-null object
# anomodalidade                368522 non-null float64
# descricaoobjeto              368522 non-null object
# especificacaoobjeto          368522 non-null object
# situacaolicitacao            368522 non-null object
# estagiolicitacao             368522 non-null object
# adjudicada                   368522 non-null object
# qtdelicitantes               368522 non-null float64
# codigomodalidade             368522 non-null float64
# numeroprocesso               368522 non-null object
# anoprocesso                  368522 non-null float64
# caracteristicaobjeto         368320 non-null object
# objetoconformeedital         272867 non-null object
# razaosocial                  341446 non-null object
# datapublicacaohomologacao    324740 non-null object
# totaladjudicadolicitacao     323414 non-null float64
# resultadohabilitacao         280490 non-null object
# dataemissaoedital            352027 non-null object
# datapublicacaohabilitacao    277349 non-null object
# totaladjudicadolicitante     158578 non-null float64
# dtypes: float64(8), int64(1), object(18)
# memory usage: 75.9+ MB

# %% [markdown]
# ## Número de numerodocumentoajustado de contratos que aparecem na detalhes filtrada por vencedor e situacaolicitacao

# %%
d = detalhes[(detalhes['situacaolicitacao'] == 'Em Andamento') | (detalhes['situacaolicitacao'] == 'Concluído')]
detalhes_filtrada = d[d['adjudicada'] == 'Vencedor']
print('Número de linhas da detalhes_filtrada: ', len(detalhes_filtrada))
# Out:
# Número de linhas da detalhes_filtrada:  158193

# %%
docs_detalhes_filtrada = detalhes_filtrada['numerodocumentoajustado'].unique()
print('Número de documentos únicos da detalhes_filtrada: ', len(docs_detalhes_filtrada))
# Out:
# Número de documentos únicos da detalhes_filtrada:  25634

# %%
docs_contratos = contratos['numerodocumentoajustado'].unique()
print('Número de documentos únicos da contratos: ', len(docs_contratos))
# Out:
# Número de documentos únicos da contratos:  30315

# %%
print('Diferença no número de documentos (contratos - detalhes): ',  len(docs_contratos) - len(docs_detalhes_filtrada))
# Out:
# Diferença no número de documentos (contratos - detalhes):  4681

# %%
print('Existem {} documentos na interseção de contratos e detalhes'.format(len(set(docs_contratos).intersection(docs_detalhes_filtrada))))
# Out:
# Existem 14292 documentos na interseção de contratos e detalhes

# %% [markdown]
# # Como unir contratos_pe com detalhes_pe? [numerocontrato, codigopl]

# %%
key = detalhes[detalhes['adjudicada'] == 'Vencedor'][['numerodocumentoajustado', 'anomodalidade', 'codigoug', 'totaladjudicadolicitante']]

# %%
key_unique = key.groupby(['numerodocumentoajustado', 'anomodalidade', 'codigoug']).count().sort_values('totaladjudicadolicitante', ascending=False)

# %%
repetidos = len(key_unique[key_unique['totaladjudicadolicitante'] > 1])
total = len(key_unique)
print('{}% das entradas são repetidas de {}'.format(repetidos/total*100, total))
# Out:
# 22.242720336704707% das entradas são repetidas de 107869

# %%
key_unique[key_unique['totaladjudicadolicitante'] > 1].hist(bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc353d67470>]], dtype=object)

# %%
repetidas = key_unique[key_unique['totaladjudicadolicitante'] > 1]
repetidas['foo'] = 1
repetidas.groupby('totaladjudicadolicitante').count()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                             foo
# totaladjudicadolicitante
# 2                         14218
# 3                          4759
# 4                          2139
# 5                           980
# 6                           599
# 7                           391
# 8                           244
# 9                           145
# 10                          106
# 11                           77
# 12                           69
# 13                           48
# 14                           39
# 15                           19
# 16                           15
# 17                           19
# 18                           15
# 19                            8
# 20                           10
# 21                            5
# 22                            7
# 23                            9
# 24                           10
# 25                            4
# 26                            7
# 27                            4
# 28                            4
# 29                            1
# 30                            3
# 31                            4
# 32                            3
# 33                            2
# 34                            1
# 35                            1
# 36                            4
# 37                            1
# 39                            1
# 40                            2
# 41                            2
# 43                            1
# 44                            1
# 45                            1
# 46                            1
# 49                            1
# 50                            2
# 51                            1
# 54                            1
# 58                            1
# 59                            1
# 67                            1
# 72                            1
# 73                            1
# 74                            1
# 79                            1
# 105                           1
# 161                           1

# %% [markdown]
# ### Vamos ver se é possível juntar as não repetidas por enquanto

# %%
nao_repetidas = key_unique[key_unique['totaladjudicadolicitante'] == 1].reset_index()
nao_repetidas = nao_repetidas.merge(detalhes[detalhes['adjudicada'] == 'Vencedor'], on=['numerodocumentoajustado','codigoug','anomodalidade'])

key_contratos = contratos[['numerodocumentoajustado', 'codigoug', 'anocontrato', 'valorcontrato']]

# %%
nao_repetidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83876 entries, 0 to 83875
# Data columns (total 28 columns):
# numerodocumentoajustado       83876 non-null object
# anomodalidade                 83876 non-null float64
# codigoug                      83876 non-null float64
# totaladjudicadolicitante_x    83876 non-null int64
# index                         83876 non-null int64
# codigopl                      83876 non-null float64
# ug                            83876 non-null object
# nomenatureza                  83876 non-null object
# nomemodalidade                83876 non-null object
# numeromodalidade              83876 non-null object
# descricaoobjeto               83876 non-null object
# especificacaoobjeto           83876 non-null object
# situacaolicitacao             83876 non-null object
# estagiolicitacao              83876 non-null object
# adjudicada                    83876 non-null object
# qtdelicitantes                83876 non-null float64
# codigomodalidade              83876 non-null float64
# numeroprocesso                83876 non-null object
# anoprocesso                   83876 non-null float64
# caracteristicaobjeto          83876 non-null object
# objetoconformeedital          58755 non-null object
# razaosocial                   83876 non-null object
# datapublicacaohomologacao     83876 non-null object
# totaladjudicadolicitacao      83876 non-null float64
# resultadohabilitacao          83874 non-null object
# dataemissaoedital             83876 non-null object
# datapublicacaohabilitacao     56707 non-null object
# totaladjudicadolicitante_y    83876 non-null float64
# dtypes: float64(8), int64(2), object(18)
# memory usage: 18.6+ MB

# %%
key_contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119827 entries, 0 to 119826
# Data columns (total 4 columns):
# numerodocumentoajustado    119827 non-null object
# codigoug                   119827 non-null object
# anocontrato                119827 non-null object
# valorcontrato              119827 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 3.7+ MB

# %%
key_contratos['codigoug'] = key_contratos['codigoug'].astype(float)
key_contratos['anocontrato'] = key_contratos['anocontrato'].astype(float)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
key_contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119827 entries, 0 to 119826
# Data columns (total 4 columns):
# numerodocumentoajustado    119827 non-null object
# codigoug                   119827 non-null float64
# anocontrato                119827 non-null float64
# valorcontrato              119827 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 3.7+ MB

# %%
len(key_contratos), len(nao_repetidas)
# Out:
# (119827, 83876)

# %%
merge_nao_repetidas = key_contratos.merge(nao_repetidas, 
                    left_on=['numerodocumentoajustado', 'codigoug', 'anocontrato'],
                    right_on=['numerodocumentoajustado','codigoug','anomodalidade'])
len(merge_nao_repetidas)
# Out:
# 30673

# %%
merge_nao_repetidas['diff'] = merge_nao_repetidas['totaladjudicadolicitacao'] -   merge_nao_repetidas['totaladjudicadolicitante_y']

# %%
merge_nao_repetidas['diff'].describe()
# Out:
# count    3.067300e+04
# mean     4.014119e+05
# std      1.926323e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      7.500000e+03
# max      2.556849e+09
# Name: diff, dtype: float64

# %%
print('A mediana da diferença dos valores da licitacao e contrato é: ', merge_nao_repetidas['diff'].median())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9f56cafe61c5> in <module>()
# ----> 1 print('A mediana da diferença dos valores da licitacao e contrato é: ', merge_nao_repetidas['diff'].median())
#
# NameError: name 'merge_nao_repetidas' is not defined

# %%
merge_nao_repetidas['diff'].plot(kind='box')

# %%
merge_nao_repetidas.groupby('diff').count()['codigoug'].sort_values(ascending=False)
# Out:
# diff
# 0.00          22517
# 60000.00         22
# 100947.00        19
# 3135500.00       18
# 426999.23        17
# 80433.80         17
# 30000.00         14
# 1933120.96       13
# 27000.00         12
# 70499.86         12
# 187.30           11
# 19200.00         11
# 23000.00         11
# 12000.00         11
# 35000.00         10
# 64400.00         10
# 42000.00         10
# 800.00           10
# 260000.00         9
# 15000.00          9
# 498689.81         9
# 3118500.00        9
# 288000.00         9
# 198000.00         9
# 3185500.00        9
# 4736000.00        8
# 50000.00          8
# 1463161.00        8
# 395240.00         8
# 18000.00          8
#               ...
# 251639.00         1
# 251657.28         1
# 251700.00         1
# 251715.00         1
# 252048.40         1
# 252092.70         1
# 249254.56         1
# 249254.00         1
# 249130.42         1
# 249046.01         1
# 246000.00         1
# 246169.11         1
# 246360.00         1
# 246378.00         1
# 246529.68         1
# 246551.83         1
# 246700.05         1
# 246795.74         1
# 246800.60         1
# 247122.50         1
# 247523.00         1
# 247628.79         1
# 247786.60         1
# 247970.58         1
# 247998.21         1
# 248000.00         1
# 248100.00         1
# 248496.60         1
# 248922.00         1
# 124378.50         1
# Name: codigoug, Length: 6568, dtype: int64

# %%
pd.cut(merge_nao_repetidas['diff'],[-1,1000,100000,2.556849e+09],labels=['0-1000', '1000-100000', '>100000']).value_counts()
# Out:
# 0-1000         22587
# >100000         4400
# 1000-100000     3685
# Name: diff, dtype: int64

# %%
merge_nao_repetidas[merge_nao_repetidas['diff'] > 0].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11086eb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10a6d70f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11afd90f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118caf0f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11629ab70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11629ab38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1141637b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112aca6d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x110f9e8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1141acba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b881e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111febeb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1117d2eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112536eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113c56908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115475dd8>]], dtype=object)

# %% [markdown]
# Com um simples merge, conseguimos 30673 linhas. Isso é 25% da base de contratos.
#
# Duas conclusões:
# - O diferença de preço entre a licitação e o contrato é, na mediana 0. O que indica que o preço pode ser usada como uma key para aumentar a porcentagem
# - O ano de 2013 não sofreu nenhum merge. Temos que analisar mais profundamente esse caso.

# %% [markdown]
# Ano de 2013

# %%
nao_repetidas.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113bb59e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14c4ce5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x152098c18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x157b2ec18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x15bf5bc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x15bf5bc50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x160bf3588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14673ca58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14b50cf98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13cf3ed68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x150951048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x153f920b8>]], dtype=object)

# %%
key_contratos[(key_contratos['anocontrato'] < 2018) & (key_contratos['anocontrato'] > 2000)].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0
# 102                             1  132263   63569.0
# 109                             1  166810   77354.0
# 142                             1   65953   58145.0
# 151                             1  337016   59721.0
# 154                             1  190298   67652.0
# 157                             1  242443  104141.0
# 168                             1   87894   68734.0
# 171                             1  189561   63025.0
# 172                             1  205177   73807.0
# 174                             1   71753   55692.0
# 177                             1   67723   61792.0
# 178                             1   91883   57832.0
# 182                             1   54900   58063.0
# 183                             1   99768   71137.0
# 186                             1   97132   70441.0
# 188                             1  278098   71500.0
# ...                           ...     ...       ...
# 83715                           1  142682   69235.0
# 83716                           1   80628   61231.0
# 83717                           1  125483   58786.0
# 83718                           1  175782   63599.0
# 83719                           1  186829   62723.0
# 83720                           1  143253   74340.0
# 83721                           1  124316   62829.0
# 83722                           1  205309   73820.0
# 83723                           1  128123   73047.0
# 83724                           1   69965   63078.0
# 83725                           1  163925   77052.0
# 83729                           1   96662   57360.0
# 83734                           1   74033   61918.0
# 83736                           1   87545   61381.0
# 83743                           1  204489   92943.0
# 83750                           1  131376   63300.0
# 83781                           1   93521   69697.0
# 83788                           1  276922  105757.0
# 83798                           1   90806   60970.0
# 83806                           1   85574   69494.0
# 83815                           1   63002   55381.0
# 83816                           1   73146   60223.0
# 83818                           1   62786   54293.0
# 83827                           1  106501   51512.0
# 83836                           1  127283   69184.0
# 83855                           1  110667   56128.0
# 83868                           1  166023   76990.0
# 83869                           1  220621   76388.0
# 83870                           1  158744   75028.0
# 83874                           1  191512   65942.0
#
#                                                       ug  \
# 1                       Prefeitura Municipal de Carnaíba
# 6                      Prefeitura Municipal de Ferreiros
# 12     Secretaria Executiva de Ressocialização de Per...
# 27        Prefeitura Municipal de Belém de São Francisco
# 32                  Prefeitura Municipal de Cachoeirinha
# 39                        Prefeitura Municipal de Tabira
# 45                Fundação de Atendimento Socioeducativo
# 60                       Prefeitura Municipal de Afrânio
# 64       Prefeitura Municipal do Cabo de Santo Agostinho
# 65                            Universidade de Pernambuco
# 81                Prefeitura Municipal de Joaquim Nabuco
# 90                     Prefeitura Municipal de Dormentes
# 93                       Prefeitura Municipal de Caruaru
# 99                       Prefeitura Municipal de Cabrobó
# 102      Prefeitura Municipal do Jaboatão dos Guararapes
# 109                      Prefeitura Municipal de Betânia
# 142                   Prefeitura Municipal de Macaparana
# 151                    Prefeitura Municipal de Araripina
# 154                     Instituto de Ciências Biológicas
# 157                        Faculdade de Ciências Médicas
# 168                Prefeitura Municipal de Lagoa do Ouro
# 171                     Prefeitura Municipal do Paudalho
# 172                 Fundo Estadual de Assistência Social
# 174                    Prefeitura Municipal de Alagoinha
# 177                  Prefeitura Municipal de Águas Belas
# 178         Prefeitura Municipal de Carnaubeira da Penha
# 182       Prefeitura Municipal do Brejo da Madre de Deus
# 183         Prefeitura Municipal de Camocim de São Félix
# 186                      Prefeitura Municipal de Jataúba
# 188                    Prefeitura Municipal dos Palmares
# ...                                                  ...
# 83715                      Polícia Militar de Pernambuco
# 83716  Secretaria de Trabalho, Qualificação e Empreen...
# 83717       Secretaria de Ciência, Tecnologia e Inovação
# 83718                            Hospital Getúlio Vargas
# 83725                        EQUIPAMENTOS DE INFORMÁTICA
# 83729        MATERIAL DE LIMPEZA, CONSERVAÇÃO E HIGIENE
# 83734                                 VESTUÁRIO EM GERAL
# 83736                             MATERIAL DE EXPEDIENTE
# 83743                                            SERVIÇO
# 83750                                   MATERIAL QUÍMICO
# 83781           MANUTENÇÃO E CONSERVAÇÃO DE BENS IMÓVEIS
# 83788                                              OBRAS
# 83798                                LOCAÇÃO DE VEÍCULOS
# 83806                                 LOCAÇÃO DE IMÓVEIS
# 83815                       COMBUSTÍVEIS E LUBRIFICANTES
# 83816                       COMBUSTÍVEIS E LUBRIFICANTES
# 83818                       COMBUSTÍVEIS E LUBRIFICANTES
# 83827                MATERIAL PARA CONSTRUÇÃO E REFORMAS
# 83836                  SERVIÇOS DE LIMPEZA E CONSERVAÇÃO
# 83855                     SERVIÇOS GRÁFICOS E EDITORIAIS
# 83868  APARELHOS, EQUIPAMENTOS MÉDICO-ODONTOLÓGICOS, ...
# 83869  APARELHOS, EQUIPAMENTOS MÉDICO-ODONTOLÓGICOS, ...
# 83870  APARELHOS, EQUIPAMENTOS MÉDICO-ODONTOLÓGICOS, ...
# 83874                     IMPRESSOS E MATERIAIS GRÁFICOS
#
#                                      especificacaoobjeto situacaolicitacao  \
# 1      MATERIAIS DESTINADOS A HIGIENIZAÇÃO PESSOAL, D...         Concluído
# 6      DESPESAS RELATIVAS A MÃO-DE-OBRA, CONSTANTES D...         Concluído
# 12     MEDICAMENTOS OU COMPONENTES DESTINADOS À MANIP...         Concluído
# 27     MATERIAIS DESTINADOS A HIGIENIZAÇÃO PESSOAL, D...         Concluído
# 32     MATERIAIS PARA EXPEDIENTE EM GERAL: BORRACHAS,...         Concluído
# 39     SERVIÇOS DE CÓPIAS XEROGRÁFICAS E REPRODUÇÃO D...         Concluído
# 45     MEDICAMENTOS OU COMPONENTES DESTINADOS À MANIP...         Concluído
# 60     A AQUISIÇÃO DE GÁS ENGARRAFADO PARA DIVERSOS U...         Concluído
# 64     SERVIÇOS DE ALUGUÉIS DE MÁQUINAS, EQUIPAMENTOS...         Concluído
# 65     MATERIAL BIBLIOGRÁFICO TAIS COMO:             ...         Concluído
# 81     MATERIAIS PARA EXPEDIENTE EM GERAL: BORRACHAS,...         Concluído
# 90     MÓVEIS DESTINADOS AO USO OU DECORAÇÃO INTERIOR...         Concluído
# 93     MÓVEIS DESTINADOS AO USO OU DECORAÇÃO INTERIOR...         Concluído
# 99     QUALQUER APARELHO, UTENSÍLIO OU EQUIPAMENTO DE...         Concluído
# 102    EQUIPAMENTOS E PEÇAS  MARÍTIMOS, TAIS COMO: IN...         Concluído
# 109    AQUISIÇÃO OU COM ALIENAÇÃO DE IMÓVEIS EM GERAL .          Concluído
# 142    MATERIAIS DE EDUCAÇÃO E ENSINO, TAIS COMO  AGE...         Concluído
# 151    MÓVEIS DESTINADOS AO USO OU DECORAÇÃO INTERIOR...         Concluído
# 154    MATERIAIS DE EDUCAÇÃO E ENSINO, TAIS COMO  AGE...         Concluído
# 157    COLEÇÕES BIBLIOGRÁFICAS DE OBRAS CIENTÍFICAS, ...         Concluído
# 168    TODAS AS MÁQUINAS, APARELHOS E EQUIPAMENTOS DE...         Concluído
# 171    SERVIÇOS DE FORNECIMENTO DE ÁGUA POTÁVEL EM CA...         Concluído
# 172    MÓVEIS DESTINADOS AO USO OU DECORAÇÃO INTERIOR...         Concluído
# 174    MATERIAIS PARA HOSPITAIS, CLÍNICAS, CONSULTÓRI...         Concluído
# 177    MATERIAIS DESTINADOS A HIGIENIZAÇÃO PESSOAL, D...         Concluído
# 178    CONTRATAÇÃO DE VEÍCULOS COM MOTORISTA PARA TRA...         Concluído
# 182                                                OBRAS         Concluído
# 183                                                OBRAS         Concluído
# 186    SERVIÇOS DE REPAROS, CONSERTOS, REVISÕES E ADA...         Concluído
# 188    EDIFICAÇÃO DESTINADA AO FUNCIONAMENTO DAS REPA...         Concluído
# ...                                                  ...               ...
# 83715  VESTUÁRIOS EM GERAL: UNIFORMES, FARDAS, CALÇAD...         Concluído
# 83716  TODAS AS MÁQUINAS, APARELHOS E EQUIPAMENTOS DE...         Concluído
# 83717  TODAS AS MÁQUINAS, APARELHOS E EQUIPAMENTOS DE...         Concluído
# 83718  MATERIAIS DE CONSUMO PARA APLICAÇÃO, MANUTENÇÃ...         Concluído
# 83719  SUPRIMENTOS DE INFORMÁTICA, TAIS COMO:CARTUCHO...         Concluído
# 83720  TODAS AS MÁQUINAS, APARELHOS E EQUIPAMENTOS DE...         Concluído
# 83721  MATERIAIS DE INFORMÁTICA: DISQUETES, CARTUCHOS...         Concluído
# 83722  TODAS AS MÁQUINAS, APARELHOS E EQUIPAMENTOS DE...         Concluído
# 83723  TODAS AS MÁQUINAS, APARELHOS E EQUIPAMENTOS DE...         Concluído
# 83724  MATERIAIS DE CONSUMO PARA APLICAÇÃO, MANUTENÇÃ...         Concluído
# 83725  TODAS AS MÁQUINAS, APARELHOS E EQUIPAMENTOS DE...         Concluído
# 83729  MATERIAIS DESTINADOS A HIGIENIZAÇÃO PESSOAL, D...         Concluído
# 83734  VESTUÁRIOS EM GERAL: UNIFORMES, FARDAS, CALÇAD...         Concluído
# 83736  MATERIAIS PARA EXPEDIENTE EM GERAL: BORRACHAS,...         Concluído
# 83743                                            SERVIÇO         Concluído
# 83750  TODOS OS ELEMENTOS OU COMPOSTOS QUÍMICOS DESTI...         Concluído
# 83781  SERVIÇOS DE REPAROS, CONSERTOS, REVISÕES E ADA...         Concluído
# 83788                                              OBRAS         Concluído
# 83798  LOCAÇÃO DE VEÍCULOS PARA TRANSPORTE DE SERVIDO...         Concluído
# 83806  REMUNERAÇÃO DE SERVIÇOS DE ALUGUEL DE PRÉDIOS,...         Concluído
# 83815  COMBUSTÍVEIS E LUBRIFICANTE, ENTRE OUTROS: ALC...         Concluído
# 83816  COMBUSTÍVEIS E LUBRIFICANTE, ENTRE OUTROS: ALC...         Concluído
# 83818  COMBUSTÍVEIS E LUBRIFICANTE, ENTRE OUTROS: ALC...         Concluído
# 83827  MATERIAIS DE CONSTRUÇÃO E ACABAMENTO. EXEMPLO:...         Concluído
Processo Adjudicado / Homologado / Ratificado   Vencedor
# 83870  Processo Adjudicado / Homologado / Ratificado   Vencedor
# 83874  Processo Adjudicado / Homologado / Ratificado   Vencedor
#
#        qtdelicitantes  codigomodalidade numeroprocesso  anoprocesso  \
# 1                 4.0               5.0             12       2013.0
# 6                 1.0              10.0             57       2013.0
# 12               14.0               8.0             31       2013.0
# 27                4.0               5.0              5       2013.0
# 32                2.0               9.0              8       2013.0
# 39                1.0               9.0             63       2013.0
# 45               20.0               8.0             10       2013.0
# 60                1.0               9.0             22       2013.0
# 64                1.0               9.0             13       2013.0
# 65               10.0               8.0             41       2013.0
# 81                7.0               9.0             28       2013.0
# 90                3.0               5.0             35       2013.0
# 93                3.0               9.0             52       2013.0
# 99                4.0               9.0             14       2013.0
# 102               1.0              10.0             56       2013.0
# 109               1.0               9.0             49       2013.0
# 142               3.0               9.0             26       2013.0
# 151               4.0               9.0             10       2013.0
# 154               4.0               8.0             79       2013.0
# 157               8.0               8.0             71       2013.0
# 168               6.0               9.0             86       2013.0
# 171               4.0               9.0            112       2013.0
# 172              27.0               8.0              1       2013.0
# 174               6.0               9.0              7       2013.0
# 177               2.0               9.0             58       2013.0
# 178               1.0              10.0             16       2013.0
# 182               6.0               4.0             10       2013.0
# 183               3.0               5.0             76       2013.0
# 186               3.0               5.0             56       2013.0
# 188               3.0               5.0             75       2013.0
# ...               ...               ...            ...          ...
# 83715            11.0               8.0             16       2013.0
# 83716            20.0               8.0              5       2013.0
# 83717             9.0               8.0              4       2013.0
# 83718             5.0               8.0             20       2013.0
# 83719             8.0               8.0            279       2013.0
# 83720             5.0               8.0             21       2013.0
# 83721            12.0               8.0             33       2013.0
# 83722            13.0               8.0             10       2013.0
# 83723             4.0               8.0              2       2013.0
# 83724            11.0               8.0             47       2013.0
# 83725             5.0               8.0              6       2013.0
# 83729             1.0               9.0             26       2013.0
# 83734             5.0               8.0             24       2013.0
# 83736             7.0               9.0             29       2013.0
# 83743             1.0              11.0            122       2013.0
# 83750             4.0               8.0              6       2013.0
# 83781             3.0               5.0             85       2013.0
# 83788             1.0               1.0              8       2013.0
# 83798             3.0               5.0              6       2013.0
# 83806             1.0              10.0             62       2013.0
# 83815             5.0               5.0              4       2013.0
# 83816             1.0               9.0             20       2013.0
# 83818             1.0               4.0              2       2013.0
# 83827             3.0               5.0             13       2012.0
# 83836             3.0               5.0             50       2013.0
# 83855             3.0               5.0             21       2013.0
# 83868             1.0              11.0             61       2013.0
# 83869             4.0               8.0             64       2013.0
# 83870             1.0              11.0             43       2013.0
# 83874             3.0               5.0             11       2013.0
#
#       caracteristicaobjeto                               objetoconformeedital  \
# 1                Por Itens  AQUISIÇÃO DE MATERIAL DE LIMPEZA DE USO HOSPIT...
# 6       Integral sem Itens  CONTRATAÇÃO DE PESSOA FISICA OU JURIDICA PARA ...
# 12               Por Itens  FORNECIMENTO PARCELADO DE MEDICAMENTOS CONTROL...
# 27               Por Itens  Fornecimento parcelado de Material de Limpeza ...
# 32               Por Lotes                             MATERIAL DE EXPEDIENTE
# 39               Por Itens                                               sede
# 45               Por Itens  Aquisição Parcelada de Medicamentos Clínicos,P...
# 60               Por Itens                  Aquisição de gás de cozinha (GLP)
# 64               Por Itens                                               None
# 65               Por Lotes  AQUISIÇÃO DE TÍTULOS BIBLIOGRÁFICOS PARA SEREM...
# 81               Por Itens                                     JOAQUIM NABUCO
# 90               Por Itens                               Na sede do Municipio
# 93               Por Itens  R. P. para eventual aquisição de móveis em ger...
# 99               Por Itens                                           hospital
# 102     Integral com Itens               AQUISIÇÃO DE ÂNCORAS (TIPO GARATEIA)
# 109              Por Lotes  Contratação de empresa para fornecimento de mo...
# 142              Por Lotes                                                  .
# 151              Por Itens                                         mobiliário
# 154              Por Itens  Aquisição de livros para atender as necessidad...
# 157              Por Lotes                                               None
# 168              Por Lotes  aquisição de material de expediente, equipamen...
# 171              Por Lotes  Contratação de empresa  para Serviço de abaste...
# 172              Por Itens  Aquisição de mobiliarios e equipamentos para o...
# 174              Por Lotes  Aquisição de Material para Odontologia, Sala d...
# 177              Por Itens  AQUISIÇÃO PARCELA DE PRODUTOS DE LIMPEZA E HIG...
# 178              Por Lotes  CONTRATAÇÃO EM CARÁTER EMERGENCIAL  DOS SERVIÇ...
# 182              Por Lotes                                Escola José Inacio
# 183              Por Lotes  CONTRATAÇÃO DE EMPRESA DE HENGENHARIA PARA EXE...
# 186              Por Lotes  Contratação de Empresa de Engenharia para exec...
# 188              Por Lotes  Contratação de uma Empresa Especializada em En...
# ...                    ...                                                ...
# 83715            Por Itens                                               None
# 83716            Por Lotes                        EQUIPAMENTOS DE INFORMÁTICA
# 83717            Por Itens                        Equipamentos de informatica
# 83718            Por Itens  PREGÃO ELETRÔNICO DE REGISTRO DE PREÇO PARA FO...
# 83719            Por Itens                                               None
# 83720            Por Itens  AQUISIÇÃO DE EQUIPAMENTOS DE INFORMATICA(COMPU...
# 83721            Por Itens  Aquisição de equipamentos, cabos, suprimentos ...
# 83722            Por Itens  AQUISIÇÃO DE EQUIPAMENTOS DE INFORMÁTICA  PARA...
# 83723            Por Itens  AQUISIÇÃO DE EQUIPAMENTOS DE INFORMÁTICA  PARA...
# 83724            Por Itens                                               None
# 83725            Por Itens  AQUISIÇÃO DE NOTEBOOKS PARA LABORATÓRIO DE CON...
# 83729            Por Lotes  Fornecimento Parcelado de Materiais de Limpeza...
# 83734            Por Itens  REGISTRO DE PREÇOS, POR UM PERÍODO DE 12 (DOZE...
# 83736            Por Itens               Aquisição de Material de Expediente.
# 83743            Por Lotes  CONTRATAÇÃO DE CENTRO DE FORMAÇÃO DE CONDUTORE...
# 83750            Por Itens  aquisição de kits reagentes para Detecção de H...
# 83781            Por Lotes  CONTRATAÇÃO DE EMPRESA DE ENGENHARIA, PARA EXE...
# 83788            Por Lotes  Contratação de empresa de engenharia para exec...
# 83798   Integral com Itens  Contratação de empresa para locação de veículo...
# 83806            Por Itens  Locação de imóvel para funcionamento da Casa d...
# 83815   Integral com Itens                                               None
# 83816   Integral com Itens                       Fornecimento de Combustíveis
# 83818            Por Itens                                               None
# 83827            Por Lotes     DIVERSAS LOCALIDADES DO MUNICIPIO DA ESCADA-PE
# 83836   Integral com Itens  Contratação de empresa especializada para pres...
# 83855            Por Itens                      Aquisição de Material Gráfico
# 83868            Por Itens  Aquisição de 01 broncofibroscópio  e 01 videob...
# 83869            Por Itens  Eventual aquisição de equipamentos médicos vol...
# 83870   Integral sem Itens         Aquisição de videogastroscópio para o HSE.
# 83722           Habilitado  2013-04-12T00:00:00       2013-04-25T00:00:00
# 83723           Habilitado  2013-06-06T00:00:00       2013-06-18T00:00:00
# 83724           Habilitado  2013-05-14T00:00:00       2013-09-03T00:00:00
# 83725           Habilitado  2013-05-08T00:00:00       2013-06-07T00:00:00
# 83729           Habilitado  2013-06-13T00:00:00       2013-06-25T00:00:00
# 83734           Habilitado  2013-02-22T00:00:00       2013-05-29T00:00:00
# 83736           Habilitado  2013-06-05T00:00:00       2013-07-05T00:00:00
# 83743           Habilitado  2013-07-09T00:00:00                      None
# 83750           Habilitado  2013-04-20T00:00:00       2013-06-07T00:00:00
# 83781           Habilitado  2013-08-22T00:00:00       2013-08-22T00:00:00
# 83788           Habilitado  2013-04-06T00:00:00       2013-05-29T00:00:00
# 83798           Habilitado  2013-01-28T00:00:00       2013-02-08T00:00:00
# 83806           Habilitado  2013-10-10T00:00:00                      None
# 83815           Habilitado  2013-02-07T00:00:00       2013-02-27T00:00:00
# 83816           Habilitado  2013-05-20T00:00:00       2013-06-05T00:00:00
# 83818           Habilitado  2013-01-30T00:00:00       2013-02-19T00:00:00
# 83827           Habilitado  2012-07-03T00:00:00       2012-07-16T00:00:00
# 83836           Habilitado  2013-12-04T00:00:00       2013-12-17T00:00:00
# 83855           Habilitado  2013-07-03T00:00:00       2013-07-11T00:00:00
# 83868           Habilitado  2013-09-04T00:00:00                      None
# 83869           Habilitado  2014-01-28T00:00:00       2014-05-23T00:00:00
# 83870           Habilitado  2013-11-06T00:00:00                      None
# 83874           Habilitado  2013-11-05T00:00:00       2013-11-14T00:00:00
#
#        totaladjudicadolicitante_y
# 1                         9983.94
# 6                         4000.00
# 12                       31400.00
# 27                       21649.40
# 32                       40900.00
# 39                      100860.00
# 45                        4316.00
# 60                       52020.00
# 64                       30684.00
# 65                       12843.90
# 81                       16458.99
# 90                       74000.00
# 93                      167930.00
# 99                      117359.34
# 102                      50692.50
# 109                     267434.00
# 142                     137349.18
# 151                      45500.00
# 154                      22618.22
# 157                       2295.75
# 168                      67500.00
# 171                     438000.00
# 172                       6336.00
# 174                      11570.00
# 177                       1354.10
# 178                     163002.40
# 182                     230783.04
# 183                      53969.28
# 186                      35596.58
# 188                     144548.91
# ...                           ...
# 83715                     3284.40
# 83716                    55000.00
# 83717                    12837.00
# 83718                     3953.75
# 83719                     7425.00
# 83720                     5327.88
# 83721                     7088.79
# 83722                    17640.74
# 83723                   448351.85
# 83724                    12948.00
# 83725                    18896.50
# 83729                    43034.30
# 83734                   188490.00
# 83736                    63096.00
# 83743                    96000.00
# 83750                   708480.00
# 83781                    63085.26
# 83788                  7754731.01
# 83798                    78500.00
# 83806                    30000.00
# 83815                    55150.00
# 83816                   351285.00
# 83818                   365820.00
# 83827                   139650.10
# 83836                    65172.42
# 83855                     3300.00
# 83868                    91138.19
# 83869                    20991.60
# 83870                    45000.00
# 83874                     8348.75
#
# [16851 rows x 28 columns]

# %%
len(key_contratos.merge(nao_repetidas, 
                    left_on=['anocontrato'],
                    right_on=['anomodalidade']))
